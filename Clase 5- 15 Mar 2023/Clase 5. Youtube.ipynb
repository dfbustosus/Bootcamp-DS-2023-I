# %% [markdown]
# # TXT

# %%
# Abrir el archivo
ruta="C:/Users/Windows/Desktop/Bootcamp-DS-2023-I/Clase 5- 15 Mar 2023/"
with open(ruta+'miMascota.txt', 'r',encoding='utf-8') as file:
    # Leer
    contents = file.read()
print(contents)
# Out:
# Ringo,10
# Tu eres X
# Yo soy Ringo
# ÑÑÑÑÑÑÑÑÑÑÑ

# %%
# Read
f=open('Data_txt.txt','r',encoding='utf-8')
content=f.read()
print(content)
f.close()
# Out:
# The Mysterious Affair at Styles
# The Secret Adversary
# The Murder on the Links
# The Man in the Brown Suit
# The Secret of Chimneys
# The Murder of Roger Ackroyd
# The Big Four
# The Mystery of the Blue Train
# The Seven Dials Mystery
# The Murder at the Vicarage
# Giant's Bread
# The Floating Admiral
# The Sittaford Mystery
# Peril at End House
# Lord Edgware Dies
# Murder on the Orient Express
# Unfinished Portrait
# Why Didn't They Ask Evans?
# Three Act Tragedy
# Death in the Clouds

# %%
#Readline
f=open('Data_txt.txt','r',encoding='utf-8')
content=f.readline() #
print(content)
f.close()
# Out:
# The Mysterious Affair at Styles

# %%
# Readlines
f=open('Data_txt.txt','r',encoding='utf-8')
content=f.readlines() #
print(content)
f.close()
# Out:
# ['The Mysterious Affair at Styles\n', 'The Secret Adversary\n', 'The Murder on the Links\n', 'The Man in the Brown Suit\n', 'The Secret of Chimneys\n', 'The Murder of Roger Ackroyd\n', 'The Big Four\n', 'The Mystery of the Blue Train\n', 'The Seven Dials Mystery\n', 'The Murder at the Vicarage\n', "Giant's Bread\n", 'The Floating Admiral\n', 'The Sittaford Mystery\n', 'Peril at End House\n', 'Lord Edgware Dies\n', 'Murder on the Orient Express\n', 'Unfinished Portrait\n', "Why Didn't They Ask Evans?\n", 'Three Act Tragedy\n', 'Death in the Clouds']

# %%
f=open('Data_txt.txt','r',encoding='utf-8')
for i, line in enumerate(f.readlines()):
    if i+1 in [5,9]:
        pass 
    else:
        print(i+1,line)
# Out:
# 1 The Mysterious Affair at Styles
#
# 2 The Secret Adversary
#
# 3 The Murder on the Links
#
# 4 The Man in the Brown Suit
#
# 6 The Murder of Roger Ackroyd
#
# 7 The Big Four
#
# 8 The Mystery of the Blue Train
#
# 10 The Murder at the Vicarage
#
# 11 Giant's Bread
#
# 12 The Floating Admiral
#
# 13 The Sittaford Mystery
#
# 14 Peril at End House
#
# 15 Lord Edgware Dies
#
# 16 Murder on the Orient Express
#
# 17 Unfinished Portrait
#
# 18 Why Didn't They Ask Evans?
#
# 19 Three Act Tragedy
#
# 20 Death in the Clouds

# %%
f=open('Data_txt.txt','r',encoding='utf-8')
for line in f.readlines():
    print(line)
f.close()
# Out:
# The Mysterious Affair at Styles
#
# The Secret Adversary
#
# The Murder on the Links
#
# The Man in the Brown Suit
#
# The Secret of Chimneys
#
# The Murder of Roger Ackroyd
#
# The Big Four
#
# The Mystery of the Blue Train
#
# The Seven Dials Mystery
#
# The Murder at the Vicarage
#
# Giant's Bread
#
# The Floating Admiral
#
# The Sittaford Mystery
#
# Peril at End House
#
# Lord Edgware Dies
#
# Murder on the Orient Express
#
# Unfinished Portrait
#
# Why Didn't They Ask Evans?
#
# Three Act Tragedy
#
# Death in the Clouds

# %%
nombre='Nicolas'
apellido='Perez'
dni=111111
d={'NOMBRE':nombre, 'APELLIDO':apellido,'DNI':dni}
d
# Out:
# {'NOMBRE': 'Nicolas', 'APELLIDO': 'Perez', 'DNI': 111111}

# %%
texto= "Hola soy David !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! \nCOL vs TYU"

# %%
f=open('David_r.txt','w')
#f.write(d['NOMBRE']+','+d['APELLIDO']+','+str(d['DNI']))
f.write(texto)
f.close()

# %%
with open('David_r.txt', 'w',encoding='utf-8') as file:
    file.write(texto)

# %%
# Escritura
nombre='Nicolas'
apellido='Perez'
dni=111111
d={'NOMBRE':nombre, 'APELLIDO':apellido,'DNI':dni}
f=open('David_r.txt','w')
f.write(d['NOMBRE']+','+d['APELLIDO']+','+str(d['DNI']))
f.close()

# %% [markdown]
# # JSON

# %%
import requests
import json

# GitHub raw URL
url="https://raw.githubusercontent.com/LearnWebCode/json-example/master/animals-1.json"
# Hacer el GET request a la URL
response = requests.get(url)
print(response)
# Cargar data
data = json.loads(response.text)
print(data)
# Out:
# <Response [200]>
# [{'name': 'Meowsy', 'species': 'cat', 'foods': {'likes': ['tuna', 'catnip'], 'dislikes': ['ham', 'zucchini']}}, {'name': 'Barky', 'species': 'dog', 'foods': {'likes': ['bones', 'carrots'], 'dislikes': ['tuna']}}, {'name': 'Purrpaws', 'species': 'cat', 'foods': {'likes': ['mice'], 'dislikes': ['cookies']}}]

# %%
import json
# Abrir
with open("Data_json.json", 'r') as f:
    data = json.load(f) # cargar
print(data)
# Out:
# [{'name': 'Meowsy', 'species': 'cat', 'foods': {'likes': ['tuna', 'catnip'], 'dislikes': ['ham', 'zucchini']}}, {'name': 'Barky', 'species': 'dog', 'foods': {'likes': ['bones', 'carrots'], 'dislikes': ['tuna']}}, {'name': 'Purrpaws', 'species': 'cat', 'foods': {'likes': ['mice'], 'dislikes': ['cookies']}}]

# %%
type(data)
# Out:
# list

# %%
data[0]
# Out:
# {'name': 'Meowsy',
#  'species': 'cat',
#  'foods': {'likes': ['tuna', 'catnip'], 'dislikes': ['ham', 'zucchini']}}

# %%
import json

person = {
    "name": "David",
    "age": 24,
    "city": "CH",
    "languages": ["English", "Spanish", "French"],
    "pets": 3,
    "dogs": [
        {"name": "Ringo", "age": 5},
        {"name": "Bobby", "age": 7},
        {"name": "Sam", "age": 10}
    ]
}
type(person)
# Out:
# dict

# %%
# Escritura
import json

person = {
    "name": "David",
    "age": 24,
    "city": "CH",
    "languages": ["English", "Spanish", "French"],
    "pets": 3,
    "dogs": [
        {"name": "Ringo", "age": 5},
        {"name": "Bobby", "age": 7},
        {"name": "Sam", "age": 10}
    ]
}

with open("David_json.json", "w") as outfile:
    json.dump(person, outfile)

# %% [markdown]
# # XML
#
# XML (Extensible Markup Language) es un lenguaje de marcado que se utiliza para almacenar e intercambiar datos estructurados. Está diseñado para ser legible tanto por humanos como por máquinas. XML usa etiquetas para definir elementos y atributos para proporcionar información adicional sobre esos elementos.

# %%
import xml.etree.ElementTree as ET
# Parsing the XML = analizar la extructura del XML
tree = ET.parse('Data_xml.xml')
# Obtener the elemento raiz = recuperar el elemento de nivel superior del documento XML
root = tree.getroot()
# Iterar sobre los elementos child elements
# un elemento secundario (child element) es un elemento anidado dentro de otro elemento, 
# también conocido como elemento principal.
for child in root:
    print(child.tag, child.attrib)
# encontrar el elemento div en el id id propertyDetailBulletList
div_element = root.find(".//div[@id='propertyDetailBulletList']")
# Imprimir el div element y su children
ET.dump(div_element)
# Out:
# version {'inline': '2.0', 'author': 'David BU'}
# data {}
# <div id="propertyDetailBulletList">
# 								<h2>Features at a Glance</h2>
# 								<ul>
# 									<li>4 Bedrooms</li>
# 									<li>3 Reception Rooms</li>
# 									<li>2 Bathrooms</li>
# 									<li>Family kitchen/morning room</li>
# 									<li>Annexe Potential</li>
# 									<li>Substantial Gardens</li>
# 								</ul>
# 							</div>

# %%
# Encontrar todos los li dentro de div
li_elems = div_element.findall(".//li")
# Extraer el texto en cada li 
li_values = [li.text for li in li_elems]
print(li_values)
# Out:
# ['4 Bedrooms', '3 Reception Rooms', '2 Bathrooms', 'Family kitchen/morning room', 'Annexe Potential', 'Substantial Gardens']

# %%
ref_div = root.find(".//div[@id='propertyDetailRef']")
ref_text = ref_div.text  # "Ref: 1747204"
ref_text.split(": ")[1]
# Out:
# '1747204'

# %%
# Otro ejemplo
ref_div = root.find(".//div[@id='propertyDetailRef']")
ref_text = ref_div.text  # "Ref: 1747204"
ref_number = ref_text.split(": ")[1]  # "1747204"
print(ref_number,':', ref_text)  # prints "1747204"
# Out:
# 1747204 : Ref: 1747204

# %% [markdown]
# # CSV

# %%
# Pandas
import pandas as pd 
#url="https://raw.githubusercontent.com/dfbustosus/Curso_DS_para_todos/main/Data/bank-full.csv"
url="https://raw.githubusercontent.com/dfbustosus/Curso_DS_para_todos/main/Data/glassdoordata.csv"
df=pd.read_csv(url,sep=',')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                 jobtitle  gender  age  performance    education  \
# 0       Graphic Designer  Female   18            5      College
# 1      Software Engineer    Male   21            5      College
# 2    Warehouse Associate  Female   19            4          PhD
# 3      Software Engineer    Male   20            5      Masters
# 4       Graphic Designer    Male   26            5      Masters
# ..                   ...     ...  ...          ...          ...
# 995  Marketing Associate  Female   61            1  High School
# 996       Data Scientist    Male   57            1      Masters
# 997    Financial Analyst    Male   48            1  High School
# 998    Financial Analyst    Male   65            2  High School
# 999    Financial Analyst    Male   60            1          PhD
#
#          department  seniority  income  bonus
# 0        Operations          2   42363   9938
# 1        Management          5  108476  11128
# 2    Administration          5   90208   9268
# ...

# %%
df.head(1)
# Out:
#            jobtitle  gender  age  performance education  department  \
# 0  Graphic Designer  Female   18            5   College  Operations
#
#    seniority  income  bonus
# 0          2   42363   9938

# %%
df.tail(1)
# Out:
#               jobtitle gender  age  performance education department  \
# 999  Financial Analyst   Male   60            1       PhD      Sales
#
#      seniority  income  bonus
# 999          2  123108   2244

# %%
df.dtypes
# Out:
# jobtitle       object
# gender         object
# age             int64
# performance     int64
# education      object
# department     object
# seniority       int64
# income          int64
# bonus           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   jobtitle     1000 non-null   object
#  1   gender       1000 non-null   object
#  2   age          1000 non-null   int64
#  3   performance  1000 non-null   int64
#  4   education    1000 non-null   object
#  5   department   1000 non-null   object
#  6   seniority    1000 non-null   int64
#  7   income       1000 non-null   int64
#  8   bonus        1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#                age  performance    seniority         income         bonus
# count  1000.000000  1000.000000  1000.000000    1000.000000   1000.000000
# mean     41.393000     3.037000     2.971000   94472.653000   6467.161000
# std      14.294856     1.423959     1.395029   25337.493272   2004.377365
# min      18.000000     1.000000     1.000000   34208.000000   1703.000000
# 25%      29.000000     2.000000     2.000000   76850.250000   4849.500000
# 50%      41.000000     3.000000     3.000000   93327.500000   6507.000000
# 75%      54.250000     4.000000     4.000000  111558.000000   8026.000000
# max      65.000000     5.000000     5.000000  179726.000000  11293.000000

# %%
df.isnull().sum()
# Out:
# jobtitle       0
# gender         0
# age            0
# performance    0
# education      0
# department     0
# seniority      0
# income         0
# bonus          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['jobtitle', 'gender', 'age', 'performance', 'education', 'department',
#        'seniority', 'income', 'bonus'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.head()
# Out:
#               jobtitle  gender  age  performance education      department  \
# 0     Graphic Designer  Female   18            5   College      Operations
# 1    Software Engineer    Male   21            5   College      Management
# 2  Warehouse Associate  Female   19            4       PhD  Administration
# 3    Software Engineer    Male   20            5   Masters           Sales
# 4     Graphic Designer    Male   26            5   Masters     Engineering
#
#    seniority  income  bonus
# 0          2   42363   9938
# 1          5  108476  11128
# 2          5   90208   9268
# 3          4  108080  10154
# 4          5   99464   9319

# %%
df['department'].unique()
# Out:
# array(['Operations', 'Management', 'Administration', 'Sales',
#        'Engineering'], dtype=object)

# %%
df['department'].value_counts()#.plot(kind='bar',figsize=(5,3))
# Out:
# Operations        210
# Sales             207
# Management        198
# Administration    193
# Engineering       192
# Name: department, dtype: int64

# %%
# Filtro
management=df[df['department']=='Management']
management
# Out:
#                 jobtitle  gender  age  performance    education  department  \
# 1      Software Engineer    Male   21            5      College  Management
# 11                Driver  Female   18            5      College  Management
# 15   Marketing Associate  Female   27            5          PhD  Management
# 23                Driver  Female   35            5      College  Management
# 27      Graphic Designer    Male   35            5          PhD  Management
# ..                   ...     ...  ...          ...          ...         ...
# 952               Driver  Female   51            1          PhD  Management
# 954                   IT    Male   62            1          PhD  Management
# 969              Manager    Male   52            1  High School  Management
# 975      Sales Associate    Male   56            1  High School  Management
# 982    Software Engineer    Male   62            1  High School  Management
#
#      seniority  income  bonus
# ...

# %%
mayores_30=df[df['age']>30]
mayores_30
# Out:
#                 jobtitle  gender  age  performance    education  \
# 8       Graphic Designer  Female   33            5  High School
# 9        Sales Associate  Female   35            5      College
# 14   Warehouse Associate  Female   35            5          PhD
# 20   Warehouse Associate    Male   36            5          PhD
# 23                Driver  Female   35            5      College
# ..                   ...     ...  ...          ...          ...
# 995  Marketing Associate  Female   61            1  High School
# 996       Data Scientist    Male   57            1      Masters
# 997    Financial Analyst    Male   48            1  High School
# 998    Financial Analyst    Male   65            2  High School
# 999    Financial Analyst    Male   60            1          PhD
#
#          department  seniority  income  bonus
# 8       Engineering          5  112976   9836
# 9       Engineering          5  106524   9941
# 14       Operations          4   95584   9745
# ...

# %%
df[(df['age']>30) & (df['department']=='Management')]
# Out:
#               jobtitle  gender  age  performance    education  department  \
# 23              Driver  Female   35            5      College  Management
# 27    Graphic Designer    Male   35            5          PhD  Management
# 31     Sales Associate    Male   35            5      Masters  Management
# 34      Data Scientist  Female   45            5          PhD  Management
# 38                  IT  Female   33            5      College  Management
# ..                 ...     ...  ...          ...          ...         ...
# 952             Driver  Female   51            1          PhD  Management
# 954                 IT    Male   62            1          PhD  Management
# 969            Manager    Male   52            1  High School  Management
# 975    Sales Associate    Male   56            1  High School  Management
# 982  Software Engineer    Male   62            1  High School  Management
#
#      seniority  income  bonus
# 23           1   72038   9031
# ...

# %%
df.loc[(df.job=='management') | (df.job=='technician'), ['housing','loan','month']]
# Out:
#       housing loan month
# 0         yes   no   may
# 1         yes   no   may
# 5         yes   no   may
# 6         yes  yes   may
# 9         yes   no   may
# ...       ...  ...   ...
# 45198      no   no   nov
# 45200     yes   no   nov
# 45201      no   no   nov
# 45205      no  yes   nov
# 45206      no   no   nov
#
# [17055 rows x 3 columns]

# %%
df[df['age']>30].head(5)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
dt=pd.read_csv('dataset_turnos_detalle.csv',sep=',')
dt
# Out:
#             genero                            sede  \
# 0        MASCULINO                 Centro Islámico
# 1        MASCULINO                      Club Ferro
# 2         FEMENINO                        La Rural
# 3        MASCULINO  Centro de día Parque Chacabuco
# 4         FEMENINO              Centro C. Recoleta
# ...            ...                             ...
# 1925040   FEMENINO            Casa del Historiador
# 1925041  MASCULINO                        La Rural
# 1925042   FEMENINO         Club Glorias Argentinas
# 1925043  MASCULINO           Centro de Dia N9 y 13
# 1925044   FEMENINO                Club San Lorenzo
#
#                            servicio          fecha_cita
# 0        Adultos Mayores de 80 años  01MAR2021:11:15:00
# 1        Adultos Mayores de 80 años  02MAR2021:09:00:00
# 2        Adultos Mayores de 80 años  01MAR2021:13:30:00
# 3        Adultos Mayores de 80 años  25FEB2021:13:00:00
# 4        Adultos Mayores de 80 años  01MAR2021:13:30:00
# ...

# %%
F=dt[dt['genero']=='FEMENINO']
F
# Out:
#            genero                     sede                    servicio  \
# 2        FEMENINO                 La Rural  Adultos Mayores de 80 años
# 4        FEMENINO       Centro C. Recoleta  Adultos Mayores de 80 años
# 6        FEMENINO          Centro Islámico  Adultos Mayores de 80 años
# 7        FEMENINO     Casa del Historiador  Adultos Mayores de 80 años
# 8        FEMENINO    San Lorenzo - Estadio  Adultos Mayores de 80 años
# ...           ...                      ...                         ...
# 1925037  FEMENINO             Club Atlanta  Adultos Mayores de 80 años
# 1925039  FEMENINO                 La Rural  Adultos Mayores de 80 años
# 1925040  FEMENINO     Casa del Historiador  Adultos Mayores de 80 años
# 1925042  FEMENINO  Club Glorias Argentinas  Adultos Mayores de 80 años
# 1925044  FEMENINO         Club San Lorenzo  Adultos Mayores de 80 años
#
#                  fecha_cita
# 2        01MAR2021:13:30:00
# 4        01MAR2021:13:30:00
# ...

# %%
F.to_csv('Femeninos.csv',sep=',',index=False)

# %%
t=pd.read_excel('insurance_data_1000.xlsx')
t
# Out:
#      case_id    income  age sex  approval         fraud    claims
# 0      59982  35750.95   42   M  Approved  Under Review   9518.95
# 1      87249  24078.27   19   M    Denied            No  19354.23
# 2      50406  39241.52   37   M    Denied         Fraud  13056.04
# 3      59391  33248.31   26   M  Approved            No  19238.37
# 4      96622  38649.96   54   M  Approved            No  14427.42
# ..       ...       ...  ...  ..       ...           ...       ...
# 995    96947  11353.88   81   M  Approved            No  15781.10
# 996    87668   8799.08   37   M  Approved            No  37004.41
# 997    39658  13143.52   35   M  Approved         Fraud  33580.79
# 998    77914   9473.25   36   F    Denied            No  27975.41
# 999    97965  11818.86   36   F  Approved         Fraud  22199.07
#
# [1000 rows x 7 columns]

# %%
t.to_excel('David.xlsx')

# %% [markdown]
# # Bases de datos

# %%
# !pip install -q PyMySQL

# %%
with open('host.txt', 'r') as f:
    host_D = f.read()
#print(host_D)
with open('user.txt', 'r') as f:
    user_D = f.read()
#print(user_D)
with open('password.txt', 'r') as f:
    password_D = f.read()
#print(password_D)

# %%
import pymysql
engine=pymysql.connect(host=host_D,\
               user=user_D,
               password=password_D,port=int(3306),db='truvideo'
                      )
engine

# %%
# Funcion completa
def david_query(connection,query):
    #try:
        cur = connection.cursor()
        cur.execute(query)
        result = cur.fetchall()
        columnas = [description[0] for description in cur.description]
        df=pd.DataFrame(result,columns=columnas)
        return df
    #except:
    #    print('Error no se pudo hacer el query')

# %%
import pandas as pd
query='SELECT * FROM SENTIMENT limit 2'
df=david_query(engine,query)
df
# Out:
#                                    UUID  VERSION          CREATED_AT  \
# 0  000004d2-8b42-4813-b7f3-f93a15aa840c        0 2022-12-14 12:20:53
# 1  00000f72-4b0a-48fc-90e7-a33675c858f9        0 2023-01-24 16:45:25
#
#            UPDATED_AT             CREATED_BY  \
# 0 2022-12-14 12:20:53  ML_TEXT_PROCESSOR_API
# 1 2023-01-24 16:45:25  ML_TEXT_PROCESSOR_API
#
#                         APPLICATION_UID ACCOUNT_UID  ORDER_ID CONVERSATION_ID  \
# 0  98cac44c-a9bd-4807-a9d5-3f359f18e08a        1322  27534938        12339528
# 1  98cac44c-a9bd-4807-a9d5-3f359f18e08a         742  29274509        12960730
#
#   CUSTOMER_UID  ... EXTERNAL_UID  \
# 0    109920801  ...     37732288
# 1    116066179  ...     39667214
#
#                                              MESSAGE  SOURCE  \
# 0  Good morning Dan,\nPlease keep me update on th...  GOOGLE
# 1                                                     GOOGLE
#
#   SENTIMENT_TYPE_INFERRED SENTIMENT_TYPE_MANUAL SENTIMENT_PERCENTAGE_POSITIVE  \
# ...

# %% [markdown]
# # Imagenes

# %%
# !pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 8.7 MB/s eta 0:00:00
# ...
#   WARNING: The scripts pip.exe, pip3.10.exe and pip3.exe are installed in 'C:\Users\Windows\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: C:\Users\Windows\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install -q scikit-image
# Out:
# ...
#      --------------------------------------- 12.0/12.0 MB 11.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.4/3.4 MB 23.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.0/2.0 MB 21.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 215.1/215.1 kB 6.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.2/4.2 MB 33.2 MB/s eta 0:00:00
# ...
#   WARNING: The scripts lsm2bin.exe, tiff2fsspec.exe, tiffcomment.exe and tifffile.exe are installed in 'C:\Users\Windows\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
from skimage import io 
photo = io.imread('dogormuffin.jpg')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (534, 950, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[::-1,::-1]) # ::-1 significa "toma todo en esta dimension pero alreves

# %%
plt.imshow(photo[:, ::-1]) # Efecto espejo

# %%
plt.imshow(photo[:, :,::-1]) # Cambiar de RGB a BGR

# %%
plt.imshow(photo[0:534, 0:500]) # Recortar

# %%
photo[::2, ::2].shape
# Out:
# (267, 475, 3)

# %%
plt.imshow(photo[::2, ::2]) # Reducir a la mitad
print(photo[::2, ::2].shape)
# Out:
# (267, 475, 3)

# %%
import numpy as np
photo_msk = np.where(photo> 100, 255, 0)

# %%
plt.imshow(photo_msk)

# %%
plt.imshow(photo[:,:,2].T,cmap='jet')
plt.colorbar()

# %% [markdown]
# # Videos

# %%
# !pip install -q opencv-python

# %% [markdown]
# Un poco de explicacion del codigo que vas a ver abajo:
#
# 1. `while cap.isOpened():` - Comienza el loop que va a reproducir el video .
#
# 2. `ret, frame = cap.read()` - lee el siguiente frame del video y lo almacena en la variable frame. La variable ret es booleana que indica si el frame se leyo correctamente
#
# 3. `if not ret:` - This checks whether ret is False, which would indicate that there are no more frames to read. If this is the case, the loop is broken and the program exits.
#
# 4. `cv2.imshow('frame', frame)` - hace el display del frame actual en una ventana llamada "frame".
#
# 5. `if cv2.waitKey(25) & 0xFF == ord('q'):` - Espera por evento key , si la letra "q" del teclado se presiona , el loop se rompe y el programa se termina. El parametro 25 especifica el delay en milisegundos entre frames.
#
# El loop continua la interacion leyendo cada frame y mostrandolo, hasta que el usuario presiones q o que el video se termine

# %%
import cv2
cap = cv2.VideoCapture('video_ejemplo.mp4')
# leer los frames del video
while cap.isOpened():
    ret, frame = cap.read()
    if not ret: # not False = True (solo chequear cuando no pueda leer mas frames)
        break

    # display el frame
    cv2.imshow('frame', frame)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
# Desplegar el video y cerrarlo 
cap.release()
cv2.destroyAllWindows() # cuando se acabe el video se cierra

# %% [markdown]
# # Audio

# %%
# !pip install -q pygame

# %%
import pygame
# inicializar el mixer de Pygame
pygame.mixer.init()

# Cargar el  MP3
pygame.mixer.music.load('ejemplo_mp3.mp3')

# reproducir el MP3
pygame.mixer.music.play()

# Esperar hasta que el MP3 se termine 
while pygame.mixer.music.get_busy():
    pygame.time.Clock().tick(10)

# Limpiar el objecto Pygame mixer
pygame.mixer.quit()
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.10.10)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# !pip install -q keyboard

# %%
import pygame
import keyboard
# Aqui cuando presiones q no se escuchara nada
pygame.init()

file = 'ejemplo_mp3.mp3'

pygame.mixer.init()
pygame.mixer.music.load(file)
pygame.mixer.music.play()

while pygame.mixer.music.get_busy():
    if keyboard.is_pressed('q'):
        pygame.mixer.music.stop()
        break
